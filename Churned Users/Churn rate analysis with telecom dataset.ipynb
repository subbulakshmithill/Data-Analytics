# %% [markdown]
# #### Basic Imports

# %%
import numpy as np
import pandas as pd
pd.set_option("display.precision", 2)
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'

# %%
df = pd.read_csv('/Users/subha/Downloads/telecom_churn.csv')
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
print(df.shape)
# Out:
# (3333, 21)

# %%
df['churn'] = df['churn'].astype('int64')

# %% [markdown]
# Dataframe.describe() method is used to view some basic statistical details like percentile, count, mean, std, min, max of a data frame or a series with numeric data.
# Dataframe.describe() method is used to view details like count, unique, top, and freq for object data.

# %%
df.describe(include=['object', 'bool'])
# Out:
#        state phone number international plan voice mail plan
# count   3333         3333               3333            3333
# unique    51         3333                  2               2
# top       WV     327-4795                 no              no
# freq     106            1               3010            2411

# %%
df['churn'].value_counts()
# Out:
# 0    2850
# 1     483
# Name: churn, dtype: int64

# %% [markdown]
# `Churn` value 0 states that the users are loyal and value 1 states that the users are not loyal. Based on the count it can be seen that out of 3333 users 2850 users are loyal and 483 users are not loyal.

# %%
df['churn'].value_counts(normalize=True)
# Out:
# 0    0.86
# 1    0.14
# Name: churn, dtype: float64

# %% [markdown]
# The dataframe can be sorted by single or multiple columns. It is also possible to view the dataframe in ascending or decending values by assigning ascending=(either `True` or `False`)

# %%
df.sort_values(by='state', ascending=True).head()
# Out:
#      state  account length  area code phone number international plan  \
# 181     AK             126        415     372-3750                 no
# 550     AK             111        415     364-7719                 no
# 2929    AK              71        510     332-2275                 no
# 1260    AK              76        415     366-9781                 no
# 1803    AK             101        510     411-4940                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 181               no                      0               58.2
# 550               no                      0              172.8
# 2929              no                      0              185.0
# 1260             yes                     22              160.1
# 1803              no                      0              174.9
#
#       total day calls  total day charge  ...  total eve calls  \
# 181                94              9.89  ...              118
# ...

# %%
df.sort_values(by=['churn', 'state'],
        ascending=[False, False]).head()
# Out:
#      state  account length  area code phone number international plan  \
# 54      WY              87        415     353-3759                 no
# 730     WY              94        510     353-8363                 no
# 1018    WY              76        415     408-6326                 no
# 1136    WY             106        415     338-6018                yes
# 1337    WY              97        510     346-1629                yes
#
#      voice mail plan  number vmail messages  total day minutes  \
# 54                no                      0              151.0
# 730               no                      0              271.2
# 1018              no                      0              263.4
# 1136             yes                     26              270.3
# 1337              no                      0              236.9
#
#       total day calls  total day charge  ...  total eve calls  \
# 54                 83             25.67  ...              116
# ...

# %% [markdown]
# ### Indexing and retrieving data
#
# A DataFrame can be indexed in a few different ways such as using column name (label) or row name (index value) or by using a series of index value.
# 1. Indexing on a single column: Dataframe['Name']
# 2. Boolean Indexing: Dataframe[C(Dataframe['Name'])] where C is a condition based on which the results will be outputed.
# 3. loc() method is used for indexing by name, and iloc() is used for indexing by number.

# %% [markdown]
# **Indexing on a single column:**

# %%
df['churn'].mean()
# Out:
# 0.14491449144914492

# %% [markdown]
# 14.5% is the proportion of churned users in the dataset.

# %% [markdown]
# **Boolean Indexing:**

# %%
df[df['churn'] == 1].mean()
# Out:
# account length            102.66
# area code                 437.82
# number vmail messages       5.12
# total day minutes         206.91
# total day calls           101.34
# total day charge           35.18
# total eve minutes         212.41
# total eve calls           100.56
# total eve charge           18.05
# total night minutes       205.23
# total night calls         100.40
# total night charge          9.24
# total intl minutes         10.70
# total intl calls            4.16
# total intl charge           2.89
# customer service calls      2.23
# churn                       1.00
# dtype: float64

# %% [markdown]
# **What is the churned user rate based on the state that they are located?**

# %%
df[df['churn'] == 1]['state'].value_counts()
# Out:
# TX    18
# NJ    18
# MD    17
# MI    16
# MN    15
# NY    15
# MT    14
# WA    14
# SC    14
# MS    14
# NV    14
# KS    13
# ME    13
# CT    12
# AR    11
# MA    11
# OR    11
# NC    11
# OH    10
# UT    10
# WV    10
# CA     9
# IN     9
# WY     9
# DE     9
# OK     9
# CO     9
# ID     9
# NH     9
# KY     8
# SD     8
# PA     8
# AL     8
# GA     8
# FL     8
# VT     8
# WI     7
# MO     7
# RI     6
# ND     6
# NM     6
# VA     5
# NE     5
# TN     5
# IL     5
# DC     5
# AZ     4
# LA     4
# IA     3
# AK     3
# HI     3
# Name: state, dtype: int64

# %%
sns.countplot(x='state', hue='churn', data=df)
fig=plt.gcf()
fig.set_size_inches(19,8)

# %% [markdown]
# It can be seen that for some states like TX,NJ,MD,MI,MN,NY,etc., the number of churn users are higher.

# %%
sns.lineplot(x="state", y="customer service calls", hue='churn',style="churn",markers=True,dashes=False, data=df)
fig=plt.gcf()
fig.set_size_inches(19,8)

# %% [markdown]
# It can be seen that in the states which had more churned users like AR(11),AL(8),ID(9),IN(9),etc., the users had to make more customer service calls than the regular users.

# %% [markdown]
# **What is the maximum length of international calls among loyal users (`Churn == 0`) who do not have an international plan?**

# %%
df[(df['churn'] == 0) & (df['international plan'] == 'no')]['total intl minutes'].max()
# Out:
# 18.9

# %%
df[(df['churn'] == 1) & (df['international plan'] == 'yes')]['total intl minutes'].max()
# Out:
# 20.0

# %%
df[(df['churn'] == 0) & (df['international plan'] == 'yes')]['total intl minutes'].max()
# Out:
# 13.0

# %%
df[(df['churn'] == 1) & (df['international plan'] == 'no')]['total intl minutes'].max()
# Out:
# 18.3

# %% [markdown]
# **loc() method:**

# %%
df.loc[0:5, 'total day minutes':'total day charge']
# Out:
#    total day minutes  total day calls  total day charge
# 0              265.1              110             45.07
# 1              161.6              123             27.47
# 2              243.4              114             41.38
# 3              299.4               71             50.90
# 4              166.7              113             28.34
# 5              223.4               98             37.98

# %% [markdown]
# Here the loc() method selects the rows `0` to `5` by using the series of index value and columns from `total day minutes` through `total day charge` using the label.

# %% [markdown]
# **iloc() method:**

# %%
df.iloc[0:5, 7:10]
# Out:
#    total day minutes  total day calls  total day charge
# 0              265.1              110             45.07
# 1              161.6              123             27.47
# 2              243.4              114             41.38
# 3              299.4               71             50.90
# 4              166.7              113             28.34

# %% [markdown]
# Here the iloc() method selects the rows `0` to `4` and columns `7` to `9` by using the series of index value.

# %%
columns_to_show = ['total day charge','total eve charge','total night charge','total intl charge']
df.groupby(['churn','international plan'])[columns_to_show].mean()
# Out:
#                           total day charge  total eve charge  \
# churn international plan
# 0     no                             29.68             16.91
#       yes                            31.25             17.00
# 1     no                             36.07             18.16
#       yes                            32.92             17.79
#
#                           total night charge  total intl charge
# churn international plan
# 0     no                                9.01               2.75
#       yes                               8.90               2.64
# 1     no                                9.42               2.77
#       yes                               8.76               3.18

# %%
columns_to_show = ['total day minutes','total day calls','total day charge']
df.groupby(['churn'])[columns_to_show].mean()
# Out:
#        total day minutes  total day calls  total day charge
# churn
# 0                 175.18           100.28             29.78
# 1                 206.91           101.34             35.18

# %%
columns_to_show = ['total night minutes','total night calls','total night charge']
df.groupby(['churn'])[columns_to_show].mean()
# Out:
#        total night minutes  total night calls  total night charge
# churn
# 0                   200.13             100.06                9.01
# 1                   205.23             100.40                9.24

# %%
columns_to_show = ['total eve minutes','total eve calls','total eve charge']
df.groupby(['churn'])[columns_to_show].mean()
# Out:
#        total eve minutes  total eve calls  total eve charge
# churn
# 0                 199.04           100.04             16.92
# 1                 212.41           100.56             18.05

# %%
columns_to_show = ['total intl minutes','total intl calls','total intl charge']
df.groupby(['churn'])[columns_to_show].mean()
# Out:
#        total intl minutes  total intl calls  total intl charge
# churn
# 0                   10.16              4.53               2.74
# 1                   10.70              4.16               2.89

# %%
ax = sns.lineplot(x="customer service calls", y="churn",markers=True,dashes=False, data=df)

# %% [markdown]
# It can be seen from the above plot that the churn rate increases as the number of customer service calls is >3.

# %%
columns_to_show = ['voice mail plan','international plan']
df.groupby(['churn'])[columns_to_show].count()
# Out:
#        voice mail plan  international plan
# churn
# 0                 2850                2850
# 1                  483                 483

# %%
pd.crosstab(df['churn'], [df['voice mail plan'],df['international plan']])
# Out:
# voice mail plan       no       yes
# international plan    no  yes   no yes
# churn
# 0                   1878  130  786  56
# 1                    302  101   44  36

# %%
sns.catplot(x="international plan", hue="churn", col="voice mail plan",
               data=df, kind="count",
                height=4, aspect=.7);
fig=plt.gcf()
fig.set_size_inches(15,8)

# %% [markdown]
# It can be seen that
# 1. Out of 2180 users with no international plan and voice mail plan, about 302 users are churned users i.e approximately 14%.
# 2. Among 231 users with international plan and no voice mail plan, 101 users are churned users i.e approximately 44%.
# 3. Out of 92 users with international plan and voice mail plan, about 36 users are churned users i.e approximately 39%.
# 4. Among 830 users with voice mail plan and no international plan, 44 users are churned users i.e approximately 5%.
# Hence it can be possible that the international plan or the voice mail plan is not well recieved by the users.
